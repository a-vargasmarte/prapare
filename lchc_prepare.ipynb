# %%
import numpy as np
import pandas as pd

# %%
pd.read_excel('LCHC_PRAPARE_02282019_ResourceReferrals.xlsx')
# Out:
#                                 Unnamed: 0                Bull City Bucks  \
# 0               Resources provided (Food):                            155
# 1                                      NaN                            NaN
# 2                                      NaN                      Legal aid
# 3          Resources provided (Financial):                              9
# 4                                      NaN                            NaN
# 5                                      NaN         NC Works State Program
# 6         Resources provided (Employment):                              7
# 7                                      NaN                            NaN
# 8                                      NaN   LCHC Transportation Services
# 9     Resources provided (Transportation):                             35
# 10                                     NaN                            NaN
# 11                                     NaN  Durham Crisis Response Center
# ...
